# %%
import pandas as pd
import duckdb
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import openpyxl
from matplotlib.colors import LinearSegmentedColormap

# %%
DATA_PATH = Path("../../data/raw")

print(DATA_PATH)
print(DATA_PATH.exists())

df = pd.read_excel(DATA_PATH / "country_weekly.xlsx")
# Out:
# ..\..\data\raw
# True
# c:\Users\adelo\de25\Netflix_Analytics_DE_UX\.venv\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.head()
# Out:
#           category  rank          show_title season_title  \
# 0  Films (English)     1  KPop Demon Hunters          NaN
# 1  Films (English)     2          Red Notice          NaN
# 2  Films (English)     3            Carry-On          NaN
# 3  Films (English)     4       Don't Look Up          NaN
# 4  Films (English)     5    The Adam Project          NaN
#
#    hours_viewed_first_91_days  runtime  views_first_91_days
# 0                   541800000   1.6667            325100000
# 1                   454200000   1.9667            230900000
# 2                   344100000   2.0000            172100000
# 3                   408600000   2.3833            171400000
# 4                   281000000   1.7833            157600000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   category                    40 non-null     object
#  1   rank                        40 non-null     int64
#  2   show_title                  40 non-null     object
#  3   season_title                20 non-null     object
#  4   hours_viewed_first_91_days  40 non-null     int64
#  5   runtime                     40 non-null     float64
#  6   views_first_91_days         40 non-null     int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 2.3+ KB

# %%
df.shape
# Out:
# (40, 7)

# %%
df.isnull().sum()
# Out:
# category                       0
# rank                           0
# show_title                     0
# season_title                  20
# hours_viewed_first_91_days     0
# runtime                        0
# views_first_91_days            0
# dtype: int64
